# %% [markdown]
# # Download the Data

# %%
# !pip3 install tqdm
# !pip3 install pillow --upgrade
# Out:
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (4.66.5)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.11/site-packages (11.0.0)

# %%
# %matplotlib inline

import os
import tarfile
import urllib
import shutil
import json
import random
import numpy as np
import boto3
import sagemaker

from tqdm import tqdm
from sagemaker.amazon.amazon_estimator import get_image_uri
from matplotlib import pyplot as plt
from xml.etree import ElementTree as ET
from PIL import Image, ImageDraw, ImageFont

urls = ['http://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz',
        'http://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz']

def download_and_extract(data_dir, download_dir):
    for url in urls:
        target_file = url.split('/')[-1]
        if target_file not in os.listdir(download_dir):
            print('Downloading', url)
            urllib.request.urlretrieve(url, os.path.join(download_dir, target_file))
            tf = tarfile.open(url.split('/')[-1])
            tf.extractall(data_dir)
        else:
            print('Already downloaded', url)

if not os.path.isdir('data'):
    os.mkdir('data')

download_and_extract('data', '.')
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml
# Downloading http://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz
# Downloading http://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz

# %% [markdown]
# # Visualize Data

# %%
trimaps_dir = 'data/annotations/trimaps/'

maps = [x for x in os.listdir(trimaps_dir) if x[-3:] == 'png']
print(len(maps))
# Out:
# 14780

# %%
image_dir = 'data/images/'

images = [x for x in os.listdir(image_dir) if x[-3:] == 'jpg']
print(len(images))
# Out:
# 7390

# %%
images[0]
# Out:
# 'boxer_16.jpg'

# %%
maps[0]
# Out:
# '._Abyssinian_1.png'

# %%
plt.figure(figsize=(12, 12))

for i in range(0, 4):
    index = random.randint(0, len(images) - 1)
    image_name = images[index]
    map_name = images[index].split('.')[0] + '.png'

    plt.subplot(4, 2, 1 + i*2)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(plt.imread(os.path.join(trimaps_dir, map_name)))
    plt.subplot(4, 2, 2 + i*2)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(plt.imread(os.path.join(image_dir, image_name)))
plt.show()

# %%
#Filter out hidden files
maps = [f for f in os.listdir(trimaps_dir) if not f.startswith('._')]


img = Image.open(os.path.join(trimaps_dir, maps[0]))
print(np.unique(img))
# Out:
# [1 2 3]

# %% [markdown]
# # SageMaker Setup

# %%
# Initialize an S3 client
s3 = boto3.client('s3')

# Define the bucket name
#Bucket name should be in lowercase
bucket_name = 'segmentdata-atulkumar'  #Provide a unique name (segmentdata-<your name>)

# Create the bucket
try:
    response = s3.create_bucket(
        Bucket=bucket_name,
        CreateBucketConfiguration={
            'LocationConstraint': boto3.Session().region_name 
        }
    )
    print(f"Bucket {bucket_name} created successfully!")
except Exception as e:
    print(f"Error creating bucket: {e}")
# Out:
# Bucket segmentdata-atulkumar created successfully!

# %%
role = sagemaker.get_execution_role()
training_image = sagemaker.image_uris.retrieve('semantic-segmentation', boto3.Session().region_name)
print(training_image)
# Out:
# 433757028032.dkr.ecr.us-west-2.amazonaws.com/semantic-segmentation:1

# %%
folders = ['train', 'train_annotation', 'validation', 'validation_annotation']

for folder in folders:
    if os.path.isdir(folder):
        shutil.rmtree(folder)
    os.mkdir(folder)

# %% [markdown]
# # Preparing Data for SageMaker

# %%
def get_map_file(image):
    map_file = image.split('.')[0] + '.png'
    assert map_file in maps
    return map_file
    
for image in tqdm(images):
    target_set = 'train' if random.randint(0, 99) < 75 else 'validation'
    
    image_file_path = os.path.join('data/images/', image)
    image_target_path = os.path.join(target_set, image)
    
    map_file_path = os.path.join(trimaps_dir, get_map_file(image))
    map_target_path = os.path.join(target_set + '_annotation', get_map_file(image))
    
    shutil.copy(image_file_path, image_target_path)
    shutil.copy(map_file_path, map_target_path)
# Out:
# 100%|██████████| 7390/7390 [00:03<00:00, 2293.88it/s]

# %%
train_images = os.listdir('train')
train_annots = os.listdir('train_annotation')

# %%
print(len(train_annots), len(train_images))
# Out:
# 5515 5515

# %% [markdown]
# # Uploading Data to S3

# %%
# %%time
sess = sagemaker.Session()

print('Starting upload..')
s3_train_path = sess.upload_data(path='train', bucket=bucket_name, key_prefix='train')
print('Training images uploaded')
s3_train_annotation_path = sess.upload_data(path='train_annotation', bucket=bucket_name,
                                     key_prefix='train_annotation')
print('Training Annotations uploaded')
s3_validation_path = sess.upload_data(path='validation', bucket=bucket_name,
                                      key_prefix='validation')
print('Validation images uploaded')
s3_validation_annotation_path = sess.upload_data(path='validation_annotation', bucket=bucket_name,
                                          key_prefix='validation_annotation')
print('Validation Annotations uploaded')
# Out:
# Starting upload..
# Training images uploaded
# Training Annotations uploaded
# Validation images uploaded
# Validation Annotations uploaded
# CPU times: user 1min 21s, sys: 9.86 s, total: 1min 31s
# Wall time: 16min 20s

# %%
s3_validation_annotation_path
# Out:
# 's3://segmentdata-atulkumar/validation_annotation'

# %% [markdown]
# # SageMaker Estimator

# %%
model = sagemaker.estimator.Estimator(
    training_image,
    role=role,
    instance_count=1, 
    instance_type='ml.p3.2xlarge',  
    volume_size=100,  
    max_run=36000,  
    input_mode='File',
    output_path='s3://petssegmentdata/output',
    sagemaker_session=sess
)

# %% [markdown]
# # Hyperparameters

# %%
model.set_hyperparameters(
    backbone='resnet-50', # This is the encoder. Other option is resnet-50
    algorithm='fcn', # This is the decoder. Other option is 'psp' and 'deeplab'                             
    use_pretrained_model='True', # Use the pre-trained model.
    crop_size=240, # Size of image random crop.                             
    num_classes=4, # Pascal has 21 classes. This is a mandatory parameter.
    epochs=10, # Number of epochs to run.
    learning_rate=0.0001,                             
    optimizer='rmsprop', # Other options include 'adam', 'rmsprop', 'nag', 'adagrad'.
    lr_scheduler='poly', # Other options include 'cosine' and 'step'.                           
    mini_batch_size=16, # Setup some mini batch size.
    validation_mini_batch_size=16,
    early_stopping=True, # Turn on early stopping. If OFF, other early stopping parameters are ignored.
    early_stopping_patience=3, # Tolerate these many epochs if the mIoU doens't increase.
    early_stopping_min_epochs=10, # No matter what, run these many number of epochs.                             
    num_training_samples=len(train_images)
)

# %% [markdown]
# # Data Channels

# %%
from sagemaker.inputs import TrainingInput

train_data = TrainingInput(s3_train_path, distribution='FullyReplicated',
                           content_type='image/jpeg', s3_data_type='S3Prefix')
validation_data = TrainingInput(s3_validation_path, distribution='FullyReplicated',
                                content_type='image/jpeg', s3_data_type='S3Prefix')

train_annotation_data = TrainingInput(s3_train_annotation_path, distribution='FullyReplicated',
                                      content_type='image/png', s3_data_type='S3Prefix')
validation_annotation_data = TrainingInput(s3_validation_annotation_path, distribution='FullyReplicated',
                                           content_type='image/png', s3_data_type='S3Prefix')

# %%
data_channels = {
    'train': train_data,
    'train_annotation': train_annotation_data,
    'validation': validation_data,
    'validation_annotation': validation_annotation_data
}

# %% [markdown]
# # Model Training

# %%
model.fit(inputs=data_channels, logs=True)
# Out:
# INFO:sagemaker:Creating training-job with name: semantic-segmentation-2024-10-25-06-23-11-257
# 2024-10-25 06:23:12 Starting - Starting the training job
# 2024-10-25 06:23:12 Pending - Training job waiting for capacity......
# 2024-10-25 06:23:57 Pending - Preparing the instances for training...
# 2024-10-25 06:24:40 Downloading - Downloading input data...
# 2024-10-25 06:25:15 Downloading - Downloading the training image.................................
# 2024-10-25 06:30:38 Training - Training image download completed. Training in progress....Docker entrypoint called with argument(s): train
# Running default environment configuration script
# Nvidia gpu devices, drivers and cuda toolkit versions (only available on hosts with GPU):
# Fri Oct 25 06:31:00 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.90.07              Driver Version: 550.90.07      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla V100-SXM2-16GB           On  |   00000000:00:1E.0 Off |                    0 |
# | N/A   24C    P0             23W /  300W |       1MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Checking for nvidia driver and cuda compatibility.
# CUDA Compatibility driver provided.
# Proceeding with compatibility check between driver, cuda-toolkit and cuda-compat.
# Detected cuda-toolkit version: 11.1.
# Detected cuda-compat version: 455.32.00.
# Detected Nvidia driver version: 550.90.07.
# Nvidia driver compatible with cuda-toolkit. Disabling cuda-compat.
# Running custom environment configuration script
# /opt/amazon/lib/python3.8/site-packages/mxnet/model.py:97: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if num_device is 1 and 'dist' not in kvstore:
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:495: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if cons['type'] is 'ineq':
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:743: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if len(self.X_min) is not 0:
# [10/25/2024 06:31:04 INFO 140160359892800] Reading default configuration from /opt/amazon/lib/python3.8/site-packages/algorithm/default-input.json: {'backbone': 'resnet-50', 'algorithm': 'fcn', 'use_pretrained_model': 'True', 'crop_size': '240', 'epochs': '10', 'learning_rate': '0.001', 'optimizer': 'sgd', 'lr_scheduler': 'poly', 'lr_scheduler_factor': '0.1', 'weight_decay': '0.0001', 'momentum': '0.9', 'gamma1': '0.9', 'gamma2': '0.9', 'mini_batch_size': '16', 'validation_mini_batch_size': '16', 'num_training_samples': '8', 'early_stopping_min_epochs': '5', 'early_stopping': 'False', 'early_stopping_patience': '4', 'early_stopping_tolerance': '0.0', 'precision_dtype': 'float32', '_kvstore': 'device', '_num_kv_servers': 'auto', 'syncbn': 'False', '_workers': '16', '_aux_loss': 'True', '_aux_weight': '0.5', '_hybrid': 'False', '_augmentation_type': 'default', '_logging_frequency': '20'}
# [10/25/2024 06:31:04 INFO 140160359892800] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'algorithm': 'fcn', 'backbone': 'resnet-50', 'crop_size': '240', 'early_stopping': 'True', 'early_stopping_min_epochs': '10', 'early_stopping_patience': '3', 'epochs': '10', 'learning_rate': '0.0001', 'lr_scheduler': 'poly', 'mini_batch_size': '16', 'num_classes': '4', 'num_training_samples': '5515', 'optimizer': 'rmsprop', 'use_pretrained_model': 'True', 'validation_mini_batch_size': '16'}
# [10/25/2024 06:31:04 INFO 140160359892800] Final configuration: {'backbone': 'resnet-50', 'algorithm': 'fcn', 'use_pretrained_model': 'True', 'crop_size': '240', 'epochs': '10', 'learning_rate': '0.0001', 'optimizer': 'rmsprop', 'lr_scheduler': 'poly', 'lr_scheduler_factor': '0.1', 'weight_decay': '0.0001', 'momentum': '0.9', 'gamma1': '0.9', 'gamma2': '0.9', 'mini_batch_size': '16', 'validation_mini_batch_size': '16', 'num_training_samples': '5515', 'early_stopping_min_epochs': '10', 'early_stopping': 'True', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.0', 'precision_dtype': 'float32', '_kvstore': 'device', '_num_kv_servers': 'auto', 'syncbn': 'False', '_workers': '16', '_aux_loss': 'True', '_aux_weight': '0.5', '_hybrid': 'False', '_augmentation_type': 'default', '_logging_frequency': '20', 'num_classes': '4'}
# Process 13 is a worker.
# [10/25/2024 06:31:04 INFO 140160359892800] Using default worker.
# [10/25/2024 06:31:04 INFO 140160359892800] Loaded iterator creator application/json for content type ('application/json', '1.0')
# /opt/amazon/lib/python3.8/site-packages/matplotlib/pyplot.py:2422: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if fignum is False or fignum is 0:
# /opt/amazon/lib/python3.8/site-packages/matplotlib/contour.py:871: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if self.extend is not 'neither':
# [10/25/2024 06:31:04 INFO 140160359892800] font search path ['/opt/amazon/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf', '/opt/amazon/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/afm', '/opt/amazon/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/pdfcorefonts']
# [10/25/2024 06:31:05 INFO 140160359892800] generated new fontManager
# /opt/amazon/lib/python3.8/site-packages/scipy/io/netcdf.py:770: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if typecode is not 'c':
# [10/25/2024 06:31:05 INFO 140160359892800] Loaded iterator creator application/x-image for content type ('application/x-image', '1.0')
# [10/25/2024 06:31:05 INFO 140160359892800] Loaded iterator creator application/x-recordio for content type ('application/x-recordio', '1.0')
# [10/25/2024 06:31:05 INFO 140160359892800] Loaded iterator creator image/jpeg for content type ('image/jpeg', '1.0')
# [10/25/2024 06:31:05 INFO 140160359892800] Loaded iterator creator image/png for content type ('image/png', '1.0')
# [10/25/2024 06:31:05 INFO 140160359892800] Checkpoint loading and saving are disabled.
# [10/25/2024 06:31:06 WARNING 140160359892800] /opt/ml/input/data/train/train_annotation is not a readable image file
# [10/25/2024 06:31:07 WARNING 140160359892800] label maps not provided, using defaults.
# [10/25/2024 06:31:07 INFO 140160359892800] #label_map train :{'scale': 1}
# [10/25/2024 06:31:07 WARNING 140160359892800] /opt/ml/input/data/validation/validation_annotation is not a readable image file
# [10/25/2024 06:31:07 WARNING 140160359892800] label maps not provided, using defaults.
# [10/25/2024 06:31:07 INFO 140160359892800] #label_map validation :{'scale': 1}
# /opt/amazon/python3.8/lib/python3.8/subprocess.py:848: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdout = io.open(c2pread, 'rb', bufsize)
# [10/25/2024 06:31:07 INFO 140160359892800] nvidia-smi: took 0.058 seconds to run.
# [10/25/2024 06:31:07 INFO 140160359892800] nvidia-smi identified 1 GPUs.
# [10/25/2024 06:31:07 INFO 140160359892800] Number of GPUs being used: 1
# [10/25/2024 06:31:07 INFO 140160359892800] Number of GPUs being used: 1
# [10/25/2024 06:31:07 INFO 140160359892800] Number of GPUs being used: 1
# [06:31:09] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_11.1.x.441.0/AL2_x86_64/generic-flavor/src/src/storage/storage.cc:108: Using GPUPooledRoundedStorageManager.
# [10/25/2024 06:31:12 INFO 140160359892800] LRScheduler setup: iters per epoch: 344, num_epochs 10
# #metrics {"StartTime": 1729837872.0129807, "EndTime": 1729837872.0131829, "Dimensions": {"Algorithm": "AWS/Semantic Segmentation", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [10/25/2024 06:31:20 INFO 140160359892800] #progress_notice. epoch: 0, iterations: 20 speed: 51.641389839455734 samples/sec learning_rate: 0.000099
# [10/25/2024 06:31:26 INFO 140160359892800] #progress_notice. epoch: 0, iterations: 40 speed: 52.293531341974 samples/sec learning_rate: 0.000099
# [10/25/2024 06:31:32 INFO 140160359892800] #progress_notice. epoch: 0, iterations: 60 speed: 51.76727089837136 samples/sec learning_rate: 0.000098
# [10/25/2024 06:31:38 INFO 140160359892800] #progress_notice. epoch: 0, iterations: 80 speed: 52.27894729871953 samples/sec learning_rate: 0.000098
# [10/25/2024 06:31:45 INFO 140160359892800] #progress_notice. epoch: 0, iterations: 100 speed: 51.78304919434366 samples/sec learning_rate: 0.000097
# [10/25/2024 06:31:51 INFO 140160359892800] #progress_notice. epoch: 0, iterations: 120 speed: 51.66938119652329 samples/sec learning_rate: 0.000097
# [10/25/2024 06:31:57 INFO 140160359892800] #progress_notice. epoch: 0, iterations: 140 speed: 51.522408135626534 samples/sec learning_rate: 0.000096
# [10/25/2024 06:32:04 INFO 140160359892800] #progress_notice. epoch: 0, iterations: 160 speed: 51.980106099768484 samples/sec learning_rate: 0.000096
# [10/25/2024 06:32:10 INFO 140160359892800] #progress_notice. epoch: 0, iterations: 180 speed: 51.79831735593325 samples/sec learning_rate: 0.000095
# [10/25/2024 06:32:16 INFO 140160359892800] #progress_notice. epoch: 0, iterations: 200 speed: 52.22695099486594 samples/sec learning_rate: 0.000095
# [10/25/2024 06:32:22 INFO 140160359892800] #progress_notice. epoch: 0, iterations: 220 speed: 52.034597273623184 samples/sec learning_rate: 0.000094
# [10/25/2024 06:32:29 INFO 140160359892800] #progress_notice. epoch: 0, iterations: 240 speed: 52.19908325315234 samples/sec learning_rate: 0.000094
# [10/25/2024 06:32:35 INFO 140160359892800] #progress_notice. epoch: 0, iterations: 260 speed: 51.582405267320674 samples/sec learning_rate: 0.000093
# [10/25/2024 06:32:41 INFO 140160359892800] #progress_notice. epoch: 0, iterations: 280 speed: 52.17566649302991 samples/sec learning_rate: 0.000093
# [10/25/2024 06:32:47 INFO 140160359892800] #progress_notice. epoch: 0, iterations: 300 speed: 51.63976059552556 samples/sec learning_rate: 0.000092
# [10/25/2024 06:32:54 INFO 140160359892800] #progress_notice. epoch: 0, iterations: 320 speed: 52.37732291232523 samples/sec learning_rate: 0.000092
# [10/25/2024 06:33:00 INFO 140160359892800] #progress_notice. epoch: 0, iterations: 340 speed: 52.11488922195215 samples/sec learning_rate: 0.000091
# [10/25/2024 06:33:01 INFO 140160359892800] #quality_metric. host: algo-1, epoch: 0, train loss: 0.5870609474043513 .
# [10/25/2024 06:33:01 INFO 140160359892800] #throughput_metric. host: algo-1, epoch: 0, train throughput: 51.599072915581345 samples/sec.
# [10/25/2024 06:33:06 INFO 140160359892800] #progress_notice. epoch: 0, iterations: 20 speed: 86.49933297328928 samples/sec
# [10/25/2024 06:33:10 INFO 140160359892800] #progress_notice. epoch: 0, iterations: 40 speed: 85.75434561209143 samples/sec
# [10/25/2024 06:33:14 INFO 140160359892800] #progress_notice. epoch: 0, iterations: 60 speed: 85.95545764274918 samples/sec
# [10/25/2024 06:33:18 INFO 140160359892800] #progress_notice. epoch: 0, iterations: 80 speed: 86.30232946931721 samples/sec
# [10/25/2024 06:33:22 INFO 140160359892800] #progress_notice. epoch: 0, iterations: 100 speed: 87.41752965420578 samples/sec
# [10/25/2024 06:33:25 INFO 140160359892800] #quality_metric. host: algo-1, epoch: 0, validation pixel_accuracy: 0.887112147955247 .
# [10/25/2024 06:33:25 INFO 140160359892800] #quality_metric. host: algo-1, epoch: 0, validation mIOU: 0.5507717108571872 .
# [10/25/2024 06:33:25 INFO 140160359892800] #throughput_metric. host: algo-1, epoch: 0, validation throughput: 81.10701820980672 samples/sec.
# [10/25/2024 06:33:25 INFO 140160359892800] Serializing model to /opt/ml/model/model_best.params
# [10/25/2024 06:33:25 INFO 140160359892800] Serializing model to /opt/ml/model/model_best.params
# [10/25/2024 06:33:26 INFO 140160359892800] #progress_metric: host=algo-1, completed 10.0 % of epochs
# #metrics {"StartTime": 1729837872.0142732, "EndTime": 1729838006.0153894, "Dimensions": {"Algorithm": "AWS/Semantic Segmentation", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [10/25/2024 06:33:33 INFO 140160359892800] #progress_notice. epoch: 1, iterations: 20 speed: 51.78472745231187 samples/sec learning_rate: 0.000090
# [10/25/2024 06:33:39 INFO 140160359892800] #progress_notice. epoch: 1, iterations: 40 speed: 51.92601017955825 samples/sec learning_rate: 0.000090
# [10/25/2024 06:33:46 INFO 140160359892800] #progress_notice. epoch: 1, iterations: 60 speed: 52.06838911906646 samples/sec learning_rate: 0.000089
# [10/25/2024 06:33:52 INFO 140160359892800] #progress_notice. epoch: 1, iterations: 80 speed: 51.8666145235162 samples/sec learning_rate: 0.000089
# [10/25/2024 06:33:58 INFO 140160359892800] #progress_notice. epoch: 1, iterations: 100 speed: 51.81755526025424 samples/sec learning_rate: 0.000088
# [10/25/2024 06:34:05 INFO 140160359892800] #progress_notice. epoch: 1, iterations: 120 speed: 51.9047646302216 samples/sec learning_rate: 0.000088
# [10/25/2024 06:34:11 INFO 140160359892800] #progress_notice. epoch: 1, iterations: 140 speed: 52.151419636806736 samples/sec learning_rate: 0.000087
# [10/25/2024 06:34:17 INFO 140160359892800] #progress_notice. epoch: 1, iterations: 160 speed: 52.21199783710608 samples/sec learning_rate: 0.000087
# [10/25/2024 06:34:23 INFO 140160359892800] #progress_notice. epoch: 1, iterations: 180 speed: 52.13715777370334 samples/sec learning_rate: 0.000086
# [10/25/2024 06:34:30 INFO 140160359892800] #progress_notice. epoch: 1, iterations: 200 speed: 52.09599612475615 samples/sec learning_rate: 0.000086
# [10/25/2024 06:34:36 INFO 140160359892800] #progress_notice. epoch: 1, iterations: 220 speed: 51.84221345510138 samples/sec learning_rate: 0.000085
# [10/25/2024 06:34:42 INFO 140160359892800] #progress_notice. epoch: 1, iterations: 240 speed: 52.06499584155712 samples/sec learning_rate: 0.000085
# [10/25/2024 06:34:48 INFO 140160359892800] #progress_notice. epoch: 1, iterations: 260 speed: 51.50896260375267 samples/sec learning_rate: 0.000084
# [10/25/2024 06:34:55 INFO 140160359892800] #progress_notice. epoch: 1, iterations: 280 speed: 51.653433537508064 samples/sec learning_rate: 0.000084
# [10/25/2024 06:35:01 INFO 140160359892800] #progress_notice. epoch: 1, iterations: 300 speed: 51.49746038250423 samples/sec learning_rate: 0.000083
# [10/25/2024 06:35:07 INFO 140160359892800] #progress_notice. epoch: 1, iterations: 320 speed: 52.524780829969764 samples/sec learning_rate: 0.000082
# [10/25/2024 06:35:13 INFO 140160359892800] #progress_notice. epoch: 1, iterations: 340 speed: 52.56950556724483 samples/sec learning_rate: 0.000082
# [10/25/2024 06:35:15 INFO 140160359892800] #quality_metric. host: algo-1, epoch: 1, train loss: 0.4392561301804971 .
# [10/25/2024 06:35:15 INFO 140160359892800] #throughput_metric. host: algo-1, epoch: 1, train throughput: 51.597629835139585 samples/sec.
# [10/25/2024 06:35:20 INFO 140160359892800] #progress_notice. epoch: 1, iterations: 20 speed: 81.48462620981402 samples/sec
# [10/25/2024 06:35:24 INFO 140160359892800] #progress_notice. epoch: 1, iterations: 40 speed: 85.59651230717819 samples/sec
# [10/25/2024 06:35:28 INFO 140160359892800] #progress_notice. epoch: 1, iterations: 60 speed: 85.60000612258955 samples/sec
# [10/25/2024 06:35:32 INFO 140160359892800] #progress_notice. epoch: 1, iterations: 80 speed: 76.53568817708316 samples/sec
# [10/25/2024 06:35:36 INFO 140160359892800] #progress_notice. epoch: 1, iterations: 100 speed: 86.65335488835977 samples/sec
# [10/25/2024 06:35:39 INFO 140160359892800] #quality_metric. host: algo-1, epoch: 1, validation pixel_accuracy: 0.9044578176934948 .
# [10/25/2024 06:35:39 INFO 140160359892800] #quality_metric. host: algo-1, epoch: 1, validation mIOU: 0.5780963498189103 .
# [10/25/2024 06:35:39 INFO 140160359892800] #throughput_metric. host: algo-1, epoch: 1, validation throughput: 83.35290636645594 samples/sec.
# [10/25/2024 06:35:39 INFO 140160359892800] Serializing model to /opt/ml/model/model_best.params
# [10/25/2024 06:35:39 INFO 140160359892800] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1729838006.0155864, "EndTime": 1729838139.4336355, "Dimensions": {"Algorithm": "AWS/Semantic Segmentation", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [10/25/2024 06:35:47 INFO 140160359892800] #progress_notice. epoch: 2, iterations: 20 speed: 51.744319671347455 samples/sec learning_rate: 0.000081
# [10/25/2024 06:35:53 INFO 140160359892800] #progress_notice. epoch: 2, iterations: 40 speed: 51.801436045641 samples/sec learning_rate: 0.000081
# [10/25/2024 06:35:59 INFO 140160359892800] #progress_notice. epoch: 2, iterations: 60 speed: 51.84249379671775 samples/sec learning_rate: 0.000080
# [10/25/2024 06:36:05 INFO 140160359892800] #progress_notice. epoch: 2, iterations: 80 speed: 52.34459880551519 samples/sec learning_rate: 0.000080
# [10/25/2024 06:36:12 INFO 140160359892800] #progress_notice. epoch: 2, iterations: 100 speed: 52.010239471255154 samples/sec learning_rate: 0.000079
# [10/25/2024 06:36:18 INFO 140160359892800] #progress_notice. epoch: 2, iterations: 120 speed: 51.95950017072364 samples/sec learning_rate: 0.000079
# [10/25/2024 06:36:24 INFO 140160359892800] #progress_notice. epoch: 2, iterations: 140 speed: 52.2115916207963 samples/sec learning_rate: 0.000078
# [10/25/2024 06:36:30 INFO 140160359892800] #progress_notice. epoch: 2, iterations: 160 speed: 52.433920500048835 samples/sec learning_rate: 0.000077
# [10/25/2024 06:36:37 INFO 140160359892800] #progress_notice. epoch: 2, iterations: 180 speed: 52.10792914257673 samples/sec learning_rate: 0.000077
# [10/25/2024 06:36:43 INFO 140160359892800] #progress_notice. epoch: 2, iterations: 200 speed: 51.93943315325914 samples/sec learning_rate: 0.000076
# [10/25/2024 06:36:49 INFO 140160359892800] #progress_notice. epoch: 2, iterations: 220 speed: 52.09437850921079 samples/sec learning_rate: 0.000076
# [10/25/2024 06:36:56 INFO 140160359892800] #progress_notice. epoch: 2, iterations: 240 speed: 51.536770968125914 samples/sec learning_rate: 0.000075
# [10/25/2024 06:37:02 INFO 140160359892800] #progress_notice. epoch: 2, iterations: 260 speed: 51.31722088572071 samples/sec learning_rate: 0.000075
# [10/25/2024 06:37:08 INFO 140160359892800] #progress_notice. epoch: 2, iterations: 280 speed: 51.68418434106748 samples/sec learning_rate: 0.000074
# [10/25/2024 06:37:14 INFO 140160359892800] #progress_notice. epoch: 2, iterations: 300 speed: 52.093650614988725 samples/sec learning_rate: 0.000074
# [10/25/2024 06:37:21 INFO 140160359892800] #progress_notice. epoch: 2, iterations: 320 speed: 51.981152930660414 samples/sec learning_rate: 0.000073
# [10/25/2024 06:37:27 INFO 140160359892800] #progress_notice. epoch: 2, iterations: 340 speed: 52.00761954360236 samples/sec learning_rate: 0.000073
# [10/25/2024 06:37:28 INFO 140160359892800] #quality_metric. host: algo-1, epoch: 2, train loss: 0.4145558344281238 .
# [10/25/2024 06:37:28 INFO 140160359892800] #throughput_metric. host: algo-1, epoch: 2, train throughput: 51.72296344606768 samples/sec.
# [10/25/2024 06:37:33 INFO 140160359892800] #progress_notice. epoch: 2, iterations: 20 speed: 85.80335598958733 samples/sec
# [10/25/2024 06:37:37 INFO 140160359892800] #progress_notice. epoch: 2, iterations: 40 speed: 82.28501923817325 samples/sec
# [10/25/2024 06:37:41 INFO 140160359892800] #progress_notice. epoch: 2, iterations: 60 speed: 85.96041219682462 samples/sec
# [10/25/2024 06:37:45 INFO 140160359892800] #progress_notice. epoch: 2, iterations: 80 speed: 84.89280252190666 samples/sec
# [10/25/2024 06:37:49 INFO 140160359892800] #progress_notice. epoch: 2, iterations: 100 speed: 86.24720504717266 samples/sec
# [10/25/2024 06:37:52 INFO 140160359892800] #quality_metric. host: algo-1, epoch: 2, validation pixel_accuracy: 0.8963829256439934 .
# [10/25/2024 06:37:52 INFO 140160359892800] #quality_metric. host: algo-1, epoch: 2, validation mIOU: 0.5615920553595595 .
# [10/25/2024 06:37:52 INFO 140160359892800] #throughput_metric. host: algo-1, epoch: 2, validation throughput: 83.35233651895993 samples/sec.
# [10/25/2024 06:37:52 INFO 140160359892800] #progress_metric: host=algo-1, completed 30.0 % of epochs
# #metrics {"StartTime": 1729838139.433815, "EndTime": 1729838272.679824, "Dimensions": {"Algorithm": "AWS/Semantic Segmentation", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [10/25/2024 06:38:00 INFO 140160359892800] #progress_notice. epoch: 3, iterations: 20 speed: 52.15972914721946 samples/sec learning_rate: 0.000072
# [10/25/2024 06:38:06 INFO 140160359892800] #progress_notice. epoch: 3, iterations: 40 speed: 51.430328390236426 samples/sec learning_rate: 0.000071
# [10/25/2024 06:38:12 INFO 140160359892800] #progress_notice. epoch: 3, iterations: 60 speed: 52.00866748298898 samples/sec learning_rate: 0.000071
# [10/25/2024 06:38:19 INFO 140160359892800] #progress_notice. epoch: 3, iterations: 80 speed: 52.077035896592236 samples/sec learning_rate: 0.000070
# [10/25/2024 06:38:25 INFO 140160359892800] #progress_notice. epoch: 3, iterations: 100 speed: 51.49256065306348 samples/sec learning_rate: 0.000070
# [10/25/2024 06:38:31 INFO 140160359892800] #progress_notice. epoch: 3, iterations: 120 speed: 51.75569295266946 samples/sec learning_rate: 0.000069
# [10/25/2024 06:38:37 INFO 140160359892800] #progress_notice. epoch: 3, iterations: 140 speed: 52.026932591769665 samples/sec learning_rate: 0.000069
# [10/25/2024 06:38:44 INFO 140160359892800] #progress_notice. epoch: 3, iterations: 160 speed: 51.571702479033995 samples/sec learning_rate: 0.000068
# [10/25/2024 06:38:50 INFO 140160359892800] #progress_notice. epoch: 3, iterations: 180 speed: 51.81075436839761 samples/sec learning_rate: 0.000068
# [10/25/2024 06:38:56 INFO 140160359892800] #progress_notice. epoch: 3, iterations: 200 speed: 51.82531845965534 samples/sec learning_rate: 0.000067
# [10/25/2024 06:39:03 INFO 140160359892800] #progress_notice. epoch: 3, iterations: 220 speed: 51.27554097719342 samples/sec learning_rate: 0.000066
# [10/25/2024 06:39:09 INFO 140160359892800] #progress_notice. epoch: 3, iterations: 240 speed: 51.988361103278166 samples/sec learning_rate: 0.000066
# [10/25/2024 06:39:15 INFO 140160359892800] #progress_notice. epoch: 3, iterations: 260 speed: 52.110397330063726 samples/sec learning_rate: 0.000065
# [10/25/2024 06:39:21 INFO 140160359892800] #progress_notice. epoch: 3, iterations: 280 speed: 51.83664729936615 samples/sec learning_rate: 0.000065
# [10/25/2024 06:39:28 INFO 140160359892800] #progress_notice. epoch: 3, iterations: 300 speed: 52.01697188044032 samples/sec learning_rate: 0.000064
# [10/25/2024 06:39:34 INFO 140160359892800] #progress_notice. epoch: 3, iterations: 320 speed: 52.12954383740838 samples/sec learning_rate: 0.000064
# [10/25/2024 06:39:40 INFO 140160359892800] #progress_notice. epoch: 3, iterations: 340 speed: 52.2976880617265 samples/sec learning_rate: 0.000063
# [10/25/2024 06:39:41 INFO 140160359892800] #quality_metric. host: algo-1, epoch: 3, train loss: 0.3885118345794983 .
# [10/25/2024 06:39:41 INFO 140160359892800] #throughput_metric. host: algo-1, epoch: 3, train throughput: 51.688410938178905 samples/sec.
# [10/25/2024 06:39:46 INFO 140160359892800] #progress_notice. epoch: 3, iterations: 20 speed: 85.35319472584385 samples/sec
# [10/25/2024 06:39:50 INFO 140160359892800] #progress_notice. epoch: 3, iterations: 40 speed: 84.27088191454227 samples/sec
# [10/25/2024 06:39:54 INFO 140160359892800] #progress_notice. epoch: 3, iterations: 60 speed: 85.74985305617598 samples/sec
# [10/25/2024 06:39:58 INFO 140160359892800] #progress_notice. epoch: 3, iterations: 80 speed: 84.41982433938577 samples/sec
# [10/25/2024 06:40:02 INFO 140160359892800] #progress_notice. epoch: 3, iterations: 100 speed: 85.62184893248377 samples/sec
# [10/25/2024 06:40:05 INFO 140160359892800] #quality_metric. host: algo-1, epoch: 3, validation pixel_accuracy: 0.9139977482490503 .
# [10/25/2024 06:40:05 INFO 140160359892800] #quality_metric. host: algo-1, epoch: 3, validation mIOU: 0.5926616925413527 .
# [10/25/2024 06:40:05 INFO 140160359892800] #throughput_metric. host: algo-1, epoch: 3, validation throughput: 82.19817214958977 samples/sec.
# [10/25/2024 06:40:05 INFO 140160359892800] Serializing model to /opt/ml/model/model_best.params
# [10/25/2024 06:40:05 INFO 140160359892800] #progress_metric: host=algo-1, completed 40.0 % of epochs
# #metrics {"StartTime": 1729838272.680009, "EndTime": 1729838405.905747, "Dimensions": {"Algorithm": "AWS/Semantic Segmentation", "Host": "algo-1", "Operation": "training", "epoch": 3, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [10/25/2024 06:40:13 INFO 140160359892800] #progress_notice. epoch: 4, iterations: 20 speed: 52.30608502084563 samples/sec learning_rate: 0.000063
# [10/25/2024 06:40:19 INFO 140160359892800] #progress_notice. epoch: 4, iterations: 40 speed: 51.83500571191113 samples/sec learning_rate: 0.000062
# [10/25/2024 06:40:26 INFO 140160359892800] #progress_notice. epoch: 4, iterations: 60 speed: 51.565718781888144 samples/sec learning_rate: 0.000061
# [10/25/2024 06:40:32 INFO 140160359892800] #progress_notice. epoch: 4, iterations: 80 speed: 52.13092066115959 samples/sec learning_rate: 0.000061
# [10/25/2024 06:40:38 INFO 140160359892800] #progress_notice. epoch: 4, iterations: 100 speed: 51.97789178873274 samples/sec learning_rate: 0.000060
# [10/25/2024 06:40:44 INFO 140160359892800] #progress_notice. epoch: 4, iterations: 120 speed: 51.746793433420464 samples/sec learning_rate: 0.000060
# [10/25/2024 06:40:51 INFO 140160359892800] #progress_notice. epoch: 4, iterations: 140 speed: 51.08817445943899 samples/sec learning_rate: 0.000059
# [10/25/2024 06:40:57 INFO 140160359892800] #progress_notice. epoch: 4, iterations: 160 speed: 51.738575071931024 samples/sec learning_rate: 0.000059
# [10/25/2024 06:41:03 INFO 140160359892800] #progress_notice. epoch: 4, iterations: 180 speed: 51.910144656243205 samples/sec learning_rate: 0.000058
# [10/25/2024 06:41:09 INFO 140160359892800] #progress_notice. epoch: 4, iterations: 200 speed: 52.3198683989974 samples/sec learning_rate: 0.000058
# [10/25/2024 06:41:16 INFO 140160359892800] #progress_notice. epoch: 4, iterations: 220 speed: 52.03943928900717 samples/sec learning_rate: 0.000057
# [10/25/2024 06:41:22 INFO 140160359892800] #progress_notice. epoch: 4, iterations: 240 speed: 51.110586109962355 samples/sec learning_rate: 0.000056
# [10/25/2024 06:41:28 INFO 140160359892800] #progress_notice. epoch: 4, iterations: 260 speed: 51.692823426465694 samples/sec learning_rate: 0.000056
# [10/25/2024 06:41:35 INFO 140160359892800] #progress_notice. epoch: 4, iterations: 280 speed: 52.135375589261685 samples/sec learning_rate: 0.000055
# [10/25/2024 06:41:41 INFO 140160359892800] #progress_notice. epoch: 4, iterations: 300 speed: 51.595413150863976 samples/sec learning_rate: 0.000055
# [10/25/2024 06:41:47 INFO 140160359892800] #progress_notice. epoch: 4, iterations: 320 speed: 52.58178011652652 samples/sec learning_rate: 0.000054
# [10/25/2024 06:41:53 INFO 140160359892800] #progress_notice. epoch: 4, iterations: 340 speed: 52.37221345998815 samples/sec learning_rate: 0.000054
# [10/25/2024 06:41:55 INFO 140160359892800] #quality_metric. host: algo-1, epoch: 4, train loss: 0.36388496860213904 .
# [10/25/2024 06:41:55 INFO 140160359892800] #throughput_metric. host: algo-1, epoch: 4, train throughput: 51.70155025880522 samples/sec.
# [10/25/2024 06:42:00 INFO 140160359892800] #progress_notice. epoch: 4, iterations: 20 speed: 85.28626729328755 samples/sec
# [10/25/2024 06:42:04 INFO 140160359892800] #progress_notice. epoch: 4, iterations: 40 speed: 85.50729837723233 samples/sec
# [10/25/2024 06:42:08 INFO 140160359892800] #progress_notice. epoch: 4, iterations: 60 speed: 85.98893951586037 samples/sec
# [10/25/2024 06:42:12 INFO 140160359892800] #progress_notice. epoch: 4, iterations: 80 speed: 85.63769194154946 samples/sec
# [10/25/2024 06:42:15 INFO 140160359892800] #progress_notice. epoch: 4, iterations: 100 speed: 86.15707274111486 samples/sec
# [10/25/2024 06:42:19 INFO 140160359892800] #quality_metric. host: algo-1, epoch: 4, validation pixel_accuracy: 0.9207706404320988 .
# [10/25/2024 06:42:19 INFO 140160359892800] #quality_metric. host: algo-1, epoch: 4, validation mIOU: 0.5976350698703417 .
# [10/25/2024 06:42:19 INFO 140160359892800] #throughput_metric. host: algo-1, epoch: 4, validation throughput: 83.05083175146805 samples/sec.
# [10/25/2024 06:42:19 INFO 140160359892800] Serializing model to /opt/ml/model/model_best.params
# [10/25/2024 06:42:19 INFO 140160359892800] #progress_metric: host=algo-1, completed 50.0 % of epochs
# #metrics {"StartTime": 1729838405.9059536, "EndTime": 1729838539.3929083, "Dimensions": {"Algorithm": "AWS/Semantic Segmentation", "Host": "algo-1", "Operation": "training", "epoch": 4, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [10/25/2024 06:42:26 INFO 140160359892800] #progress_notice. epoch: 5, iterations: 20 speed: 51.92854152689984 samples/sec learning_rate: 0.000053
# [10/25/2024 06:42:33 INFO 140160359892800] #progress_notice. epoch: 5, iterations: 40 speed: 51.854992103010126 samples/sec learning_rate: 0.000052
# [10/25/2024 06:42:39 INFO 140160359892800] #progress_notice. epoch: 5, iterations: 60 speed: 51.856474673660315 samples/sec learning_rate: 0.000052
# [10/25/2024 06:42:45 INFO 140160359892800] #progress_notice. epoch: 5, iterations: 80 speed: 52.077399609044285 samples/sec learning_rate: 0.000051
# [10/25/2024 06:42:52 INFO 140160359892800] #progress_notice. epoch: 5, iterations: 100 speed: 52.01177124353717 samples/sec learning_rate: 0.000051
# [10/25/2024 06:42:58 INFO 140160359892800] #progress_notice. epoch: 5, iterations: 120 speed: 52.08443238183789 samples/sec learning_rate: 0.000050
# [10/25/2024 06:43:04 INFO 140160359892800] #progress_notice. epoch: 5, iterations: 140 speed: 52.197865225957344 samples/sec learning_rate: 0.000050
# [10/25/2024 06:43:10 INFO 140160359892800] #progress_notice. epoch: 5, iterations: 160 speed: 51.96613896899169 samples/sec learning_rate: 0.000049
# [10/25/2024 06:43:17 INFO 140160359892800] #progress_notice. epoch: 5, iterations: 180 speed: 51.80155600274489 samples/sec learning_rate: 0.000048
# [10/25/2024 06:43:23 INFO 140160359892800] #progress_notice. epoch: 5, iterations: 200 speed: 51.73889418288016 samples/sec learning_rate: 0.000048
# [10/25/2024 06:43:29 INFO 140160359892800] #progress_notice. epoch: 5, iterations: 220 speed: 52.09777561789039 samples/sec learning_rate: 0.000047
# [10/25/2024 06:43:35 INFO 140160359892800] #progress_notice. epoch: 5, iterations: 240 speed: 51.61811333409737 samples/sec learning_rate: 0.000047
# [10/25/2024 06:43:42 INFO 140160359892800] #progress_notice. epoch: 5, iterations: 260 speed: 52.04496835835712 samples/sec learning_rate: 0.000046
# [10/25/2024 06:43:48 INFO 140160359892800] #progress_notice. epoch: 5, iterations: 280 speed: 52.37491112659865 samples/sec learning_rate: 0.000046
# [10/25/2024 06:43:54 INFO 140160359892800] #progress_notice. epoch: 5, iterations: 300 speed: 51.890195981399316 samples/sec learning_rate: 0.000045
# [10/25/2024 06:44:01 INFO 140160359892800] #progress_notice. epoch: 5, iterations: 320 speed: 52.3029052725432 samples/sec learning_rate: 0.000044
# [10/25/2024 06:44:07 INFO 140160359892800] #progress_notice. epoch: 5, iterations: 340 speed: 52.207895342830646 samples/sec learning_rate: 0.000044
# [10/25/2024 06:44:08 INFO 140160359892800] #quality_metric. host: algo-1, epoch: 5, train loss: 0.3655031609794368 .
# [10/25/2024 06:44:08 INFO 140160359892800] #throughput_metric. host: algo-1, epoch: 5, train throughput: 51.594529542861025 samples/sec.
# [10/25/2024 06:44:13 INFO 140160359892800] #progress_notice. epoch: 5, iterations: 20 speed: 85.54141327361097 samples/sec
# [10/25/2024 06:44:17 INFO 140160359892800] #progress_notice. epoch: 5, iterations: 40 speed: 85.35721154090754 samples/sec
# [10/25/2024 06:44:21 INFO 140160359892800] #progress_notice. epoch: 5, iterations: 60 speed: 85.23427311499645 samples/sec
# [10/25/2024 06:44:25 INFO 140160359892800] #progress_notice. epoch: 5, iterations: 80 speed: 85.56420802998814 samples/sec
# [10/25/2024 06:44:29 INFO 140160359892800] #progress_notice. epoch: 5, iterations: 100 speed: 86.19259381036538 samples/sec
# [10/25/2024 06:44:32 INFO 140160359892800] #quality_metric. host: algo-1, epoch: 5, validation pixel_accuracy: 0.9229931548669962 .
# [10/25/2024 06:44:32 INFO 140160359892800] #quality_metric. host: algo-1, epoch: 5, validation mIOU: 0.5996772503605231 .
# [10/25/2024 06:44:32 INFO 140160359892800] #throughput_metric. host: algo-1, epoch: 5, validation throughput: 83.13144549720195 samples/sec.
# [10/25/2024 06:44:32 INFO 140160359892800] Serializing model to /opt/ml/model/model_best.params
# [10/25/2024 06:44:32 INFO 140160359892800] #progress_metric: host=algo-1, completed 60.0 % of epochs
# #metrics {"StartTime": 1729838539.3931189, "EndTime": 1729838672.9001756, "Dimensions": {"Algorithm": "AWS/Semantic Segmentation", "Host": "algo-1", "Operation": "training", "epoch": 5, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [10/25/2024 06:44:40 INFO 140160359892800] #progress_notice. epoch: 6, iterations: 20 speed: 51.46586561284222 samples/sec learning_rate: 0.000043
# [10/25/2024 06:44:46 INFO 140160359892800] #progress_notice. epoch: 6, iterations: 40 speed: 52.23341438431866 samples/sec learning_rate: 0.000043
# [10/25/2024 06:44:52 INFO 140160359892800] #progress_notice. epoch: 6, iterations: 60 speed: 51.99782738226682 samples/sec learning_rate: 0.000042
# [10/25/2024 06:44:59 INFO 140160359892800] #progress_notice. epoch: 6, iterations: 80 speed: 51.82499828173785 samples/sec learning_rate: 0.000041
# [10/25/2024 06:45:05 INFO 140160359892800] #progress_notice. epoch: 6, iterations: 100 speed: 51.863167331293084 samples/sec learning_rate: 0.000041
# [10/25/2024 06:45:11 INFO 140160359892800] #progress_notice. epoch: 6, iterations: 120 speed: 52.24923407757247 samples/sec learning_rate: 0.000040
# [10/25/2024 06:45:18 INFO 140160359892800] #progress_notice. epoch: 6, iterations: 140 speed: 51.82399775124369 samples/sec learning_rate: 0.000040
# [10/25/2024 06:45:24 INFO 140160359892800] #progress_notice. epoch: 6, iterations: 160 speed: 51.4767219412215 samples/sec learning_rate: 0.000039
# [10/25/2024 06:45:30 INFO 140160359892800] #progress_notice. epoch: 6, iterations: 180 speed: 51.12417496023354 samples/sec learning_rate: 0.000039
# [10/25/2024 06:45:36 INFO 140160359892800] #progress_notice. epoch: 6, iterations: 200 speed: 52.09162879331825 samples/sec learning_rate: 0.000038
# [10/25/2024 06:45:43 INFO 140160359892800] #progress_notice. epoch: 6, iterations: 220 speed: 51.88814980163716 samples/sec learning_rate: 0.000037
# [10/25/2024 06:45:49 INFO 140160359892800] #progress_notice. epoch: 6, iterations: 240 speed: 52.21045424875501 samples/sec learning_rate: 0.000037
# [10/25/2024 06:45:55 INFO 140160359892800] #progress_notice. epoch: 6, iterations: 260 speed: 51.73179489472313 samples/sec learning_rate: 0.000036
# [10/25/2024 06:46:01 INFO 140160359892800] #progress_notice. epoch: 6, iterations: 280 speed: 51.91259414200048 samples/sec learning_rate: 0.000036
# [10/25/2024 06:46:08 INFO 140160359892800] #progress_notice. epoch: 6, iterations: 300 speed: 51.99029436099895 samples/sec learning_rate: 0.000035
# [10/25/2024 06:46:14 INFO 140160359892800] #progress_notice. epoch: 6, iterations: 320 speed: 52.40280329680198 samples/sec learning_rate: 0.000034
# [10/25/2024 06:46:20 INFO 140160359892800] #progress_notice. epoch: 6, iterations: 340 speed: 52.330843202879606 samples/sec learning_rate: 0.000034
# [10/25/2024 06:46:21 INFO 140160359892800] #quality_metric. host: algo-1, epoch: 6, train loss: 0.3455810992610316 .
# [10/25/2024 06:46:21 INFO 140160359892800] #throughput_metric. host: algo-1, epoch: 6, train throughput: 51.789162094067265 samples/sec.
# [10/25/2024 06:46:26 INFO 140160359892800] #progress_notice. epoch: 6, iterations: 20 speed: 85.69116437761444 samples/sec
# [10/25/2024 06:46:30 INFO 140160359892800] #progress_notice. epoch: 6, iterations: 40 speed: 83.93969648112731 samples/sec
# [10/25/2024 06:46:34 INFO 140160359892800] #progress_notice. epoch: 6, iterations: 60 speed: 85.4088123634244 samples/sec
# [10/25/2024 06:46:38 INFO 140160359892800] #progress_notice. epoch: 6, iterations: 80 speed: 85.25907076076365 samples/sec
# [10/25/2024 06:46:42 INFO 140160359892800] #progress_notice. epoch: 6, iterations: 100 speed: 85.97472856200316 samples/sec
# [10/25/2024 06:46:45 INFO 140160359892800] #quality_metric. host: algo-1, epoch: 6, validation pixel_accuracy: 0.9244945152985518 .
# [10/25/2024 06:46:45 INFO 140160359892800] #quality_metric. host: algo-1, epoch: 6, validation mIOU: 0.6030271642176877 .
# [10/25/2024 06:46:45 INFO 140160359892800] #throughput_metric. host: algo-1, epoch: 6, validation throughput: 82.67053955104414 samples/sec.
# [10/25/2024 06:46:45 INFO 140160359892800] Serializing model to /opt/ml/model/model_best.params
# [10/25/2024 06:46:45 INFO 140160359892800] #progress_metric: host=algo-1, completed 70.0 % of epochs
# #metrics {"StartTime": 1729838672.9003274, "EndTime": 1729838805.8037155, "Dimensions": {"Algorithm": "AWS/Semantic Segmentation", "Host": "algo-1", "Operation": "training", "epoch": 6, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 7.0, "count": 1, "min": 7, "max": 7}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [10/25/2024 06:46:53 INFO 140160359892800] #progress_notice. epoch: 7, iterations: 20 speed: 52.523711988929996 samples/sec learning_rate: 0.000033
# [10/25/2024 06:46:59 INFO 140160359892800] #progress_notice. epoch: 7, iterations: 40 speed: 51.15983621866683 samples/sec learning_rate: 0.000033
# [10/25/2024 06:47:05 INFO 140160359892800] #progress_notice. epoch: 7, iterations: 60 speed: 51.70341721380815 samples/sec learning_rate: 0.000032
# [10/25/2024 06:47:12 INFO 140160359892800] #progress_notice. epoch: 7, iterations: 80 speed: 51.8709842977666 samples/sec learning_rate: 0.000031
# [10/25/2024 06:47:18 INFO 140160359892800] #progress_notice. epoch: 7, iterations: 100 speed: 51.677657178279766 samples/sec learning_rate: 0.000031
# [10/25/2024 06:47:24 INFO 140160359892800] #progress_notice. epoch: 7, iterations: 120 speed: 51.75545346364833 samples/sec learning_rate: 0.000030
# [10/25/2024 06:47:30 INFO 140160359892800] #progress_notice. epoch: 7, iterations: 140 speed: 51.77541848840376 samples/sec learning_rate: 0.000030
# [10/25/2024 06:47:37 INFO 140160359892800] #progress_notice. epoch: 7, iterations: 160 speed: 51.42122519598401 samples/sec learning_rate: 0.000029
# [10/25/2024 06:47:43 INFO 140160359892800] #progress_notice. epoch: 7, iterations: 180 speed: 51.61501667844708 samples/sec learning_rate: 0.000028
# [10/25/2024 06:47:49 INFO 140160359892800] #progress_notice. epoch: 7, iterations: 200 speed: 51.931957227958144 samples/sec learning_rate: 0.000028
# [10/25/2024 06:47:56 INFO 140160359892800] #progress_notice. epoch: 7, iterations: 220 speed: 52.01914920004961 samples/sec learning_rate: 0.000027
# [10/25/2024 06:48:02 INFO 140160359892800] #progress_notice. epoch: 7, iterations: 240 speed: 51.511611609229725 samples/sec learning_rate: 0.000027
# [10/25/2024 06:48:08 INFO 140160359892800] #progress_notice. epoch: 7, iterations: 260 speed: 52.16791964558485 samples/sec learning_rate: 0.000026
# [10/25/2024 06:48:14 INFO 140160359892800] #progress_notice. epoch: 7, iterations: 280 speed: 51.83812882120525 samples/sec learning_rate: 0.000025
# [10/25/2024 06:48:21 INFO 140160359892800] #progress_notice. epoch: 7, iterations: 300 speed: 51.79168139434735 samples/sec learning_rate: 0.000025
# [10/25/2024 06:48:27 INFO 140160359892800] #progress_notice. epoch: 7, iterations: 320 speed: 52.09906987107377 samples/sec learning_rate: 0.000024
# [10/25/2024 06:48:33 INFO 140160359892800] #progress_notice. epoch: 7, iterations: 340 speed: 52.194252079716776 samples/sec learning_rate: 0.000023
# [10/25/2024 06:48:35 INFO 140160359892800] #quality_metric. host: algo-1, epoch: 7, train loss: 0.32912436347940693 .
# [10/25/2024 06:48:35 INFO 140160359892800] #throughput_metric. host: algo-1, epoch: 7, train throughput: 51.71739733566174 samples/sec.
# [10/25/2024 06:48:40 INFO 140160359892800] #progress_notice. epoch: 7, iterations: 20 speed: 85.23264931841938 samples/sec
# [10/25/2024 06:48:44 INFO 140160359892800] #progress_notice. epoch: 7, iterations: 40 speed: 84.53254261968404 samples/sec
# [10/25/2024 06:48:48 INFO 140160359892800] #progress_notice. epoch: 7, iterations: 60 speed: 80.89547539402706 samples/sec
# [10/25/2024 06:48:51 INFO 140160359892800] #progress_notice. epoch: 7, iterations: 80 speed: 85.46646171009682 samples/sec
# [10/25/2024 06:48:55 INFO 140160359892800] #progress_notice. epoch: 7, iterations: 100 speed: 85.75182533983138 samples/sec
# [10/25/2024 06:48:58 INFO 140160359892800] #quality_metric. host: algo-1, epoch: 7, validation pixel_accuracy: 0.9246506169129867 .
# [10/25/2024 06:48:58 INFO 140160359892800] #quality_metric. host: algo-1, epoch: 7, validation mIOU: 0.6054554036839025 .
# [10/25/2024 06:48:58 INFO 140160359892800] #throughput_metric. host: algo-1, epoch: 7, validation throughput: 83.12420228213007 samples/sec.
# [10/25/2024 06:48:59 INFO 140160359892800] Serializing model to /opt/ml/model/model_best.params
# [10/25/2024 06:48:59 INFO 140160359892800] #progress_metric: host=algo-1, completed 80.0 % of epochs
# #metrics {"StartTime": 1729838805.8038602, "EndTime": 1729838939.1869962, "Dimensions": {"Algorithm": "AWS/Semantic Segmentation", "Host": "algo-1", "Operation": "training", "epoch": 7, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 8.0, "count": 1, "min": 8, "max": 8}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [10/25/2024 06:49:06 INFO 140160359892800] #progress_notice. epoch: 8, iterations: 20 speed: 52.01201311056634 samples/sec learning_rate: 0.000023
# [10/25/2024 06:49:13 INFO 140160359892800] #progress_notice. epoch: 8, iterations: 40 speed: 52.209195073223256 samples/sec learning_rate: 0.000022
# [10/25/2024 06:49:19 INFO 140160359892800] #progress_notice. epoch: 8, iterations: 60 speed: 51.71672533800238 samples/sec learning_rate: 0.000021
# [10/25/2024 06:49:25 INFO 140160359892800] #progress_notice. epoch: 8, iterations: 80 speed: 51.91632904880341 samples/sec learning_rate: 0.000021
# [10/25/2024 06:49:31 INFO 140160359892800] #progress_notice. epoch: 8, iterations: 100 speed: 52.10501617293785 samples/sec learning_rate: 0.000020
# [10/25/2024 06:49:38 INFO 140160359892800] #progress_notice. epoch: 8, iterations: 120 speed: 52.321092126754685 samples/sec learning_rate: 0.000020
# [10/25/2024 06:49:44 INFO 140160359892800] #progress_notice. epoch: 8, iterations: 140 speed: 51.86837838046729 samples/sec learning_rate: 0.000019
# [10/25/2024 06:49:50 INFO 140160359892800] #progress_notice. epoch: 8, iterations: 160 speed: 51.80983438483369 samples/sec learning_rate: 0.000018
# [10/25/2024 06:49:56 INFO 140160359892800] #progress_notice. epoch: 8, iterations: 180 speed: 51.3996426243596 samples/sec learning_rate: 0.000018
# [10/25/2024 06:50:03 INFO 140160359892800] #progress_notice. epoch: 8, iterations: 200 speed: 51.5618360657753 samples/sec learning_rate: 0.000017
# [10/25/2024 06:50:09 INFO 140160359892800] #progress_notice. epoch: 8, iterations: 220 speed: 51.79427961049055 samples/sec learning_rate: 0.000016
# [10/25/2024 06:50:15 INFO 140160359892800] #progress_notice. epoch: 8, iterations: 240 speed: 51.6007292349876 samples/sec learning_rate: 0.000016
# [10/25/2024 06:50:21 INFO 140160359892800] #progress_notice. epoch: 8, iterations: 260 speed: 51.9150438589366 samples/sec learning_rate: 0.000015
# [10/25/2024 06:50:28 INFO 140160359892800] #progress_notice. epoch: 8, iterations: 280 speed: 52.08184539400416 samples/sec learning_rate: 0.000014
# [10/25/2024 06:50:34 INFO 140160359892800] #progress_notice. epoch: 8, iterations: 300 speed: 51.91171069425643 samples/sec learning_rate: 0.000014
# [10/25/2024 06:50:40 INFO 140160359892800] #progress_notice. epoch: 8, iterations: 320 speed: 52.091790533276516 samples/sec learning_rate: 0.000013
# [10/25/2024 06:50:46 INFO 140160359892800] #progress_notice. epoch: 8, iterations: 340 speed: 52.20298132220232 samples/sec learning_rate: 0.000013
# [10/25/2024 06:50:48 INFO 140160359892800] #quality_metric. host: algo-1, epoch: 8, train loss: 0.31691539913847827 .
# [10/25/2024 06:50:48 INFO 140160359892800] #throughput_metric. host: algo-1, epoch: 8, train throughput: 51.6779807288991 samples/sec.
# [10/25/2024 06:50:53 INFO 140160359892800] #progress_notice. epoch: 8, iterations: 20 speed: 85.74448452139559 samples/sec
# [10/25/2024 06:50:57 INFO 140160359892800] #progress_notice. epoch: 8, iterations: 40 speed: 85.07263051409535 samples/sec
# [10/25/2024 06:51:01 INFO 140160359892800] #progress_notice. epoch: 8, iterations: 60 speed: 84.49029119490758 samples/sec
# [10/25/2024 06:51:05 INFO 140160359892800] #progress_notice. epoch: 8, iterations: 80 speed: 85.72367410912166 samples/sec
# [10/25/2024 06:51:09 INFO 140160359892800] #progress_notice. epoch: 8, iterations: 100 speed: 86.69734994360896 samples/sec
# [10/25/2024 06:51:12 INFO 140160359892800] #quality_metric. host: algo-1, epoch: 8, validation pixel_accuracy: 0.9263139356303419 .
# [10/25/2024 06:51:12 INFO 140160359892800] #quality_metric. host: algo-1, epoch: 8, validation mIOU: 0.6064252479163076 .
# [10/25/2024 06:51:12 INFO 140160359892800] #throughput_metric. host: algo-1, epoch: 8, validation throughput: 82.90472280159685 samples/sec.
# [10/25/2024 06:51:12 INFO 140160359892800] Serializing model to /opt/ml/model/model_best.params
# [10/25/2024 06:51:12 INFO 140160359892800] #progress_metric: host=algo-1, completed 90.0 % of epochs
# #metrics {"StartTime": 1729838939.1871428, "EndTime": 1729839072.5745544, "Dimensions": {"Algorithm": "AWS/Semantic Segmentation", "Host": "algo-1", "Operation": "training", "epoch": 8, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 9.0, "count": 1, "min": 9, "max": 9}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [10/25/2024 06:51:20 INFO 140160359892800] #progress_notice. epoch: 9, iterations: 20 speed: 52.21021053262162 samples/sec learning_rate: 0.000012
# [10/25/2024 06:51:26 INFO 140160359892800] #progress_notice. epoch: 9, iterations: 40 speed: 51.871585700483095 samples/sec learning_rate: 0.000011
# [10/25/2024 06:51:32 INFO 140160359892800] #progress_notice. epoch: 9, iterations: 60 speed: 51.98248166136066 samples/sec learning_rate: 0.000010
# [10/25/2024 06:51:38 INFO 140160359892800] #progress_notice. epoch: 9, iterations: 80 speed: 52.04355571065744 samples/sec learning_rate: 0.000010
# [10/25/2024 06:51:45 INFO 140160359892800] #progress_notice. epoch: 9, iterations: 100 speed: 52.500619206430045 samples/sec learning_rate: 0.000009
# [10/25/2024 06:51:51 INFO 140160359892800] #progress_notice. epoch: 9, iterations: 120 speed: 51.88642471663393 samples/sec learning_rate: 0.000008
# [10/25/2024 06:51:57 INFO 140160359892800] #progress_notice. epoch: 9, iterations: 140 speed: 51.92866207340551 samples/sec learning_rate: 0.000008
# [10/25/2024 06:52:04 INFO 140160359892800] #progress_notice. epoch: 9, iterations: 160 speed: 51.426938945664766 samples/sec learning_rate: 0.000007
# [10/25/2024 06:52:10 INFO 140160359892800] #progress_notice. epoch: 9, iterations: 180 speed: 51.746833334746995 samples/sec learning_rate: 0.000006
# [10/25/2024 06:52:16 INFO 140160359892800] #progress_notice. epoch: 9, iterations: 200 speed: 51.813514515132795 samples/sec learning_rate: 0.000005
# [10/25/2024 06:52:22 INFO 140160359892800] #progress_notice. epoch: 9, iterations: 220 speed: 51.961310583841005 samples/sec learning_rate: 0.000005
# [10/25/2024 06:52:29 INFO 140160359892800] #progress_notice. epoch: 9, iterations: 240 speed: 51.54282712315342 samples/sec learning_rate: 0.000004
# [10/25/2024 06:52:35 INFO 140160359892800] #progress_notice. epoch: 9, iterations: 260 speed: 51.818475518039094 samples/sec learning_rate: 0.000003
# [10/25/2024 06:52:41 INFO 140160359892800] #progress_notice. epoch: 9, iterations: 280 speed: 52.30767503998553 samples/sec learning_rate: 0.000002
# [10/25/2024 06:52:47 INFO 140160359892800] #progress_notice. epoch: 9, iterations: 300 speed: 52.21772616003747 samples/sec learning_rate: 0.000002
# [10/25/2024 06:52:54 INFO 140160359892800] #progress_notice. epoch: 9, iterations: 320 speed: 52.36146642676683 samples/sec learning_rate: 0.000001
# [10/25/2024 06:53:00 INFO 140160359892800] #progress_notice. epoch: 9, iterations: 340 speed: 52.51861503774815 samples/sec learning_rate: 0.000000
# [10/25/2024 06:53:01 INFO 140160359892800] #quality_metric. host: algo-1, epoch: 9, train loss: 0.3211925241143204 .
# [10/25/2024 06:53:01 INFO 140160359892800] #throughput_metric. host: algo-1, epoch: 9, train throughput: 51.70964603094202 samples/sec.
# [10/25/2024 06:53:06 INFO 140160359892800] #progress_notice. epoch: 9, iterations: 20 speed: 85.12464356385408 samples/sec
# [10/25/2024 06:53:10 INFO 140160359892800] #progress_notice. epoch: 9, iterations: 40 speed: 84.22635447206716 samples/sec
# [10/25/2024 06:53:14 INFO 140160359892800] #progress_notice. epoch: 9, iterations: 60 speed: 85.98023612614747 samples/sec
# [10/25/2024 06:53:18 INFO 140160359892800] #progress_notice. epoch: 9, iterations: 80 speed: 85.35200061048508 samples/sec
# [10/25/2024 06:53:22 INFO 140160359892800] #progress_notice. epoch: 9, iterations: 100 speed: 86.46055098115254 samples/sec
# [10/25/2024 06:53:25 INFO 140160359892800] #quality_metric. host: algo-1, epoch: 9, validation pixel_accuracy: 0.9263718430971035 .
# [10/25/2024 06:53:25 INFO 140160359892800] #quality_metric. host: algo-1, epoch: 9, validation mIOU: 0.6075262080266352 .
# [10/25/2024 06:53:25 INFO 140160359892800] #throughput_metric. host: algo-1, epoch: 9, validation throughput: 84.05384914807041 samples/sec.
# [10/25/2024 06:53:25 INFO 140160359892800] Serializing model to /opt/ml/model/model_best.params
# [10/25/2024 06:53:25 INFO 140160359892800] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1729839072.574761, "EndTime": 1729839205.596213, "Dimensions": {"Algorithm": "AWS/Semantic Segmentation", "Host": "algo-1", "Operation": "training", "epoch": 9, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 10.0, "count": 1, "min": 10, "max": 10}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [10/25/2024 06:53:25 WARNING 140160359892800] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [10/25/2024 06:53:25 INFO 140160359892800] Serializing model to /opt/ml/model/model_algo-1
# [10/25/2024 06:53:25 INFO 140160359892800] Test data is not provided.
# #metrics {"StartTime": 1729837865.887227, "EndTime": 1729839205.872695, "Dimensions": {"Algorithm": "AWS/Semantic Segmentation", "Host": "algo-1", "Operation": "training"}, "Metrics": {"epochs": {"sum": 10.0, "count": 1, "min": 10, "max": 10}, "setuptime": {"sum": 13.335943222045898, "count": 1, "min": 13.335943222045898, "max": 13.335943222045898}, "totaltime": {"sum": 1341241.9531345367, "count": 1, "min": 1341241.9531345367, "max": 1341241.9531345367}}}
#
# 2024-10-25 06:53:33 Uploading - Uploading generated training model
# 2024-10-25 06:53:51 Completed - Training job completed
# Training seconds: 1752
# Billable seconds: 1752

# %% [markdown]
# # Deploy Model

# %%
deployed_model = model.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
print('\nModel deployed!')
# Out:
# INFO:sagemaker:Creating model with name: semantic-segmentation-2024-10-25-07-02-38-848
# INFO:sagemaker:Creating endpoint-config with name semantic-segmentation-2024-10-25-07-02-38-848
# INFO:sagemaker:Creating endpoint with name semantic-segmentation-2024-10-25-07-02-38-848
# -------------------!
# Model deployed!

# %% [markdown]
# # Predictions

# %%
image_dir = 'validation'
images = [x for x in os.listdir(image_dir) if x[-3:] == 'jpg']
print(len(images))
# Out:
# 1875

# %%
deployed_model.content_type = 'image/jpeg'
deployed_model.accept = 'image/png'

# %%
index = 583

image_path = os.path.join(image_dir, images[index])
# image_path = 'dog_cat.jfif'

with open(image_path, 'rb') as f:
    b = bytearray(f.read())

results = deployed_model.predict(b)

# %%
import io

mask = np.array(Image.open(io.BytesIO(results)))

# %%
plt.imshow(plt.imread(image_path));

# %%
plt.imshow(mask);

# %% [markdown]
# Delete endpoint

# %%
sagemaker.Session().delete_endpoint(deployed_model.endpoint)
